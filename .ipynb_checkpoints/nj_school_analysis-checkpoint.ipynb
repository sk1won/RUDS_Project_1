# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
school_data_2012_2013_load = '2012-2013 nj high school.csv'
school_data_2013_2014_load = '2013-2014 nj high school.csv'
school_data_2014_2015_load = '2014-2015 nj high school.csv'
school_data_2015_2016_load = '2015-2016 nj high school.csv'
school_data_2016_2017_load = '2016-2017 nj high school.csv'

# %%
school_data_2012_2013 = pd.read_csv(school_data_2012_2013_load, converters={'zip': '{:0>5}'.format})
#school_data_2012_2013['zip'] = school_data_2012_2013['zip'].apply(lambda x: x.zfill(5))
school_data_2013_2014 = pd.read_csv(school_data_2013_2014_load, converters={'zip': '{:0>5}'.format})
school_data_2014_2015 = pd.read_csv(school_data_2014_2015_load, converters={'zip': '{:0>5}'.format})
school_data_2015_2016 = pd.read_csv(school_data_2015_2016_load, converters={'zip': '{:0>5}'.format})
school_data_2016_2017 = pd.read_csv(school_data_2016_2017_load, converters={'zip': '{:0>5}'.format})

# %%
school_data_2012_2013.columns
# Out:
# Index(['rank', 'school', 'grades', 'students', 'student/teacher ratio',
#        'free lunch recipients', 'average standard score', 'rank (2012)',
#        'rank change from 2012', 'school type', 'address', 'city', 'zip',
#        'county', 'district', 'charter', 'magnet', 'virtual', 'title i',
#        'phone', 'full time teachers', 'white', 'black', 'hispanic', 'asian',
#        'american indian', 'pacific islander', 'two or more races'],
#       dtype='object')

# %%
data_1213_list_w = school_data_2012_2013['white'].tolist()
data_1213_list_b = school_data_2012_2013['black'].tolist()
data_1213_list_h = school_data_2012_2013['hispanic'].tolist()
data_1213_list_a = school_data_2012_2013['asian'].tolist()
data_1213_list_i = school_data_2012_2013['american indian'].tolist()
data_1213_list_p = school_data_2012_2013['pacific islander'].tolist()
data_1213_list_t = school_data_2012_2013['two or more races'].tolist()

# %%
list_1213_w = []
list_1213_b = []
list_1213_h = []
list_1213_a = []
list_1213_i = []
list_1213_p = []
list_1213_t = []

# %%
for a in data_1213_list_w:
    b = int(a.split(' ')[0])
    print(b)
    list_1213_w.append(b)
# Out:
# 112
# 154
# 48
# 32
# 100
# 176
# 474
# 216
# 137
# 45
# 272
# 212
# 62
# 53
# 185
# 150
# 133
# 271
# 404
# 175
# 116
# 293
# 8
# 1012
# 137
# 1392
# 396
# 19
# 1077
# 671
# 1263
# 533
# 221
# 1140
# 1443
# 1194
# 828
# 974
# 1192
# 718
# 602
# 902
# 645
# 48
# 1709
# 873
# 484
# 787
# 98
# 722
# 1241
# 668
# 924
# 696
# 594
# 1102
# 601
# 1091
# 682
# 1947
# 1050
# 1029
# 1608
# 686
# 610
# 1462
# 618
# 2594
# 25
# 628
# 2102
# 1010
# 1590
# 871
# 517
# 1271
# 393
# 1046
# 628
# 791
# 456
# 846
# 830
# 668
# 1039
# 1094
# 320
# 1701
# 11
# 1514
# 1789
# 764
# 971
# 1325
# 615
# 1142
# 448
# 1071
# 925
# 1091
# 1207
# 498
# 434
# 1120
# 431
# 1606
# 1216
# 1127
# 916
# 1049
# 915
# 586
# 757
# 539
# 326
# 956
# 1406
# 770
# 879
# 1405
# 457
# 1142
# 810
# 779
# 463
# 385
# 2085
# 728
# 1384
# 507
# 831
# 1061
# 834
# 584
# 1230
# 648
# 590
# 1195
# 1032
# 1282
# 732
# 4
# 1910
# 452
# 704
# 665
# 402
# 719
# 1338
# 1314
# 25
# 90
# 45
# 222
# 100
# 146
# 39
# 170
# 150
# 73
# 72
# 71
# 140
# 236
# 74
# 336
# ...

# %%
for a in data_1213_list_a:
    b = int(a.split(' ')[0])
    print(b)
    list_1213_a.append(b)
# Out:
# 64
# 40
# 2
# 52
# 4
# 94
# 465
# 84
# 276
# 42
# 10
# 21
# 128
# 102
# 3
# 82
# 31
# 190
# 98
# 27
# 40
# 21
# 2
# 86
# 140
# 316
# 46
# 17
# 552
# 38
# 53
# 13
# 120
# 298
# 387
# 48
# 101
# 69
# 298
# 417
# 795
# 59
# 74
# 15
# 147
# 355
# 61
# 330
# 60
# 196
# 418
# 57
# 270
# 108
# 826
# 51
# 64
# 148
# 7
# 530
# 108
# 32
# 114
# 36
# 5
# 342
# 69
# 166
# 24
# 20
# 61
# 37
# 74
# 80
# 29
# 141
# 19
# 30
# 24
# 66
# 79
# 15
# 67
# 39
# 95
# 119
# 180
# 125
# 2
# 39
# 312
# 65
# 293
# 113
# 54
# 17
# 5
# 202
# 39
# 92
# 106
# 30
# 1462
# 143
# 25
# 317
# 122
# 17
# 7
# 11
# 15
# 69
# 71
# 103
# 93
# 194
# 278
# 17
# 94
# 47
# 477
# 83
# 367
# 223
# 149
# 23
# 127
# 14
# 154
# 48
# 93
# 49
# 11
# 24
# 1171
# 15
# 345
# 77
# 38
# 37
# 59
# 5
# 133
# 44
# 71
# 28
# 4
# 611
# 611
# 22
# 180
# 46
# 116
# 21
# 4
# 73
# 6
# 13
# 18
# 41
# 71
# 313
# 93
# 15
# 32
# 27
# 49
# 83
# 14
# 0
# 6
# 332
# 24
# 18
# 125
# 17
# 14
# 38
# 18
# 23
# 254
# 120
# 46
# 5
# 12
# 27
# 145
# 50
# 504
# ...

# %%
for a in data_1213_list_i:
    b = int(a.split(' ')[0])
    print(b)
    list_1213_i.append(b)

# %%
for a in data_1213_list_p:
    b = int(a.split(' ')[0])
    print(b)
    list_1213_p.append(b)

# %%
for a in data_1213_list_t:
    b = int(a.split(' ')[0])
    print(b)
    list_1213_t.append(b)

# %%
list_1213_race = [list_1213_w, list_1213_b, 
                  list_1213_h, list_1213_a,
                  list_1213_i, list_1213_p, list_1213_t]

# %%
list_1213_w = pd.DataFrame({
                            'index' : list(range(0, len(school_data_2012_2013['white']))),
                            'white 1213' : list_1213_race[0]})
list_1213_b = pd.DataFrame({'black 1213' : list_1213_race[1]})
list_1213_h = pd.DataFrame({'hispanic 1213' : list_1213_race[2]})
list_1213_a = pd.DataFrame({'asian 1213' : list_1213_race[3]})
list_1213_i = pd.DataFrame({'american indian 1213' : list_1213_race[4]})
list_1213_p = pd.DataFrame({'pacific islander 1213' : list_1213_race[5]})
list_1213_t = pd.DataFrame({'two or more races 1213' : list_1213_race[6]})

# %%
data_1213_race = pd.merge(list_1213_w, list_1213_b, how = 'outer')

# %%
merge_data_1213 = pd.merge(
    school_data_2012_2013[['rank', 'school', 
                                        'students', 'full time teachers', 'student/teacher ratio',
                                        'free lunch recipients', 'average standard score', 
                                        'rank (2012)', 'rank change from 2012', 
                                        'school type', 'zip', 'county', 'district',
                                        'charter', 'magnet', 'virtual', 'title i']]

# %%
len(list_1213_race[0])

# %%
list(range(0, len(school_data_2012_2013['white'])))+
